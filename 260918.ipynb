# %%
print("hello world")
# Out:
# hello world

# %%
#100분을 몇시간 몇분인지 출력 해보세요.
print("100분은", 100//60, "시간",  100%60, "분 입니다.")
# Out:
# 100분은 1 시간 40 분 입니다.

# %%
time=300
print(time, "분은", time//60, "시간",  time%60, "분 입니다.")
# Out:
# 300 분은 5 시간 0 분 입니다.

# %%
time=int(input("시간을 입력하세요: "))
print(f"{time}분은 {time//60}시간 {time%60}분 입니다.")
# Out:
# 시간을 입력하세요: 200
# 200분은 3시간 20분 입니다.

# %%
a=10
#a=a+7
a+=7
a
# Out:
# 17

# %%
name=input("이름을 입력하세요: ")
age=int(input("나이를 입력하세요: "))
print(name, age)

print(type(age)) #input함수는 입력 데이터를 문자열로 출력함
# Out:
# 이름을 입력하세요: 홍길동
# 나이를 입력하세요: 19
# 홍길동 19
# <class 'int'>

# %%
age=age+1
age
print(f"{name}님의 나이는 {age}세입니다.")
# Out:
# 22

# %%
if False:
    print("참")
else:
    print("거짓")
# Out:
# 거짓

# %%
#숫자를 입력받아서 짝수인지 홀수인지 출력하는 프로그램을 작성하시오.
num1=int(input("숫자를 입력하세요."))
if num1%2==0:
    print("짝수")
else:
    print("홀수")
# Out:
# 숫자를 입력하세요.2
# 짝수
